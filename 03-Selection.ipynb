# %%
import pandas as pd

df=pd.read_csv('avocado.csv')
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
df.loc[24]
# Out:
# Date              2015-07-12
# AveragePrice            1.05
# Total Volume          124055
# 4046                  672.25
# 4225                 94693.5
# 4770                 4257.64
# Total Bags           24431.9
# Small Bags           24290.1
# Large Bags            108.49
# XLarge Bags            33.33
# type            conventional
# year                    2015
# region                Albany
# Name: 24, dtype: object

# %%
df.loc[25:30]
# Out:
#           Date  AveragePrice  Total Volume    4046      4225     4770  \
# 25  2015-07-05          1.35     109252.12  869.45  72600.55  5883.16
# 26  2015-06-28          1.37      89534.81  664.23  57545.79  4662.71
# 27  2015-06-21          1.27     104849.39  804.01  76688.55  5481.18
# 28  2015-06-14          1.32      89631.30  850.58  55400.94  4377.19
# 29  2015-06-07          1.07     122743.06  656.71  99220.82    90.32
# 30  2015-05-31          1.23      95123.62  922.37  70469.69    50.55
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 25    29898.96    29663.19      235.77          0.0  conventional  2015
# 26    26662.08    26311.76      350.32          0.0  conventional  2015
# 27    21875.65    21662.00      213.65          0.0  conventional  2015
# 28    29002.59    28343.14      659.45          0.0  conventional  2015
# 29    22775.21    22314.99      460.22          0.0  conventional  2015
# ...

# %%
df.iloc[24,5]
# Out:
# 4257.64

# %%
df.iloc[105:110,12]
# Out:
# 105    BaltimoreWashington
# 106    BaltimoreWashington
# 107    BaltimoreWashington
# 108    BaltimoreWashington
# 109    BaltimoreWashington
# Name: region, dtype: object

# %%
df['region']
# Out:
# 0                  Albany
# 1                  Albany
# 2                  Albany
# 3                  Albany
# 4                  Albany
# 5                  Albany
# 6                  Albany
# 7                  Albany
# 8                  Albany
# 9                  Albany
# 10                 Albany
# 11                 Albany
# 12                 Albany
# 13                 Albany
# 14                 Albany
# 15                 Albany
# 16                 Albany
# 17                 Albany
# 18                 Albany
# 19                 Albany
# 20                 Albany
# 21                 Albany
# 22                 Albany
# 23                 Albany
# 24                 Albany
# 25                 Albany
# 26                 Albany
# 27                 Albany
# 28                 Albany
# 29                 Albany
#                ...
# 18219             TotalUS
# 18220             TotalUS
# 18221             TotalUS
# 18222             TotalUS
# ...
